# %% [markdown]
# <a href="https://colab.research.google.com/github/vijaykankane/B12DevopsHeroviered/blob/main/05_Bivariate_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load dataset
url = "https://raw.githubusercontent.com/vijaykankane/GenAIProject/main/HousingPrices_New.csv"
df = pd.read_csv(url)

# Clean column names
df.columns = df.columns.str.strip()

# Use the actual columns in your dataset
x_col = 'Flat Area (in Sqft)'
y_col = 'Sale Price'

# Scatter plot
plt.figure(figsize=(10, 5))
sns.scatterplot(x=x_col, y=y_col, data=df)
plt.title(f"{y_col} vs {x_col}")
plt.xlabel(x_col)
plt.ylabel(y_col)
plt.show()
